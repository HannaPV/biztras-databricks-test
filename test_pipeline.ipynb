# %%
print("Git test successful!")

# %%
print('pull success')

# %%
print('error solving')

# %% [markdown]
# Added a cell extra

# %%
data = [10, 20, None, 40]

if None in data:
    print("❌ Data contains null values")
else:
    print("✅ Data is clean")
